# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_csv("/Users/Steven/Desktop/showwcase_sessions.csv")

df['True_duration']= df['session_duration']-df['inactive_duration']

neg_duration=df[df['True_duration'] < 0].index
df.drop(neg_duration, inplace= True)                                              

df.head(300)
# Out:
#      session_id  customer_id login_date projects_added likes_given  \
# 0      624205.0      80746.0   10/30/19          False        True
# 1      624241.0      24520.0   10/30/19           True        True
# 2      111002.0      32047.0   10/30/19           True        True
# 3      545113.0      23404.0   10/30/19           True        True
# 4      750269.0      40235.0   10/30/19           True        True
# ..          ...          ...        ...            ...         ...
# 297    643880.0      51243.0    10/1/19           True       False
# 298    844518.0      23083.0    10/1/19           True       False
# 299    933954.0      38459.0    10/1/19           True       False
# 300         NaN          NaN        NaN            NaN         NaN
# 301         NaN          NaN        NaN            NaN         NaN
#
#     comment_given inactive_status bug_occured  session_projects_added  \
# 0            True            True       False                     0.0
# ...

# %%
import scipy
import scipy.stats
from scipy.stats import norm
from numpy import mean
from numpy import std

plt.bar(df['session_projects_added'], df['True_duration'])
plt.xlabel('session_projects_added')
plt.ylabel('True_duration')
plt.show()

plt.scatter(df['session_projects_added'], df['True_duration'])
plt.xlabel('session_projects_added')
plt.ylabel('True_duration')
plt.show()

# %%
plt.bar(df['bugs_in_session'], df['True_duration'])
plt.xlabel('bugs_in_session')
plt.ylabel('True_duration')
plt.show()
plt.scatter(df['bugs_in_session'], df['True_duration'])
plt.xlabel('bugs_in_session')
plt.ylabel('True_duration')
plt.show()

# %%
plt.bar(df['session_likes_given'],df['True_duration'])
plt.xlabel('session_likes_given')
plt.ylabel('True_duration')
plt.show()
plt.scatter(df['session_likes_given'],df['True_duration'])
plt.xlabel('session_likes_given')
plt.ylabel('True_duration')
plt.show()

# %%
plt.bar(df['session_comments_given'], df['True_duration'])
plt.xlabel('session_comments_given')
plt.ylabel('True_duration')
plt.show()

plt.scatter(df['session_comments_given'], df['True_duration'])
plt.xlabel('session_comments_given')
plt.ylabel('True_duration')
plt.show()

# %%
x= df['login_date'].astype('str')
y= df['True_duration']
plt.bar(x,y)
plt.xlabel('Date')
plt.xticks(rotation=60)
plt.ylabel('duration')
plt.show()

plt.scatter(x,y)
plt.xlabel('Date')
plt.xticks(rotation=60)
plt.ylabel('duration')
plt.show()

# %%
import seaborn as sns

df['Week']=pd.to_datetime(df['login_date'])
start_date='10/2/19'
end_date='10/13/19'
Week=(df['Week']>start_date )& (df['Week']< end_date)
df1=df.loc[Week]
df1.head()

plt.bar(df1['session_likes_given'], df1['True_duration'])
plt.xlabel('session_likes_given')
plt.ylabel('True_duration')
plt.show()

plt.bar(df1['bugs_in_session'], df1['True_duration'])
plt.xlabel('bugs_in_session')
plt.ylabel('True_duration')
plt.show()



plt.bar(df1['session_projects_added'], df1['True_duration'])
plt.xlabel('session_projects_added')
plt.ylabel('True_duration')
plt.show()


plt.bar(df1['session_comments_given'], df1['True_duration'])
plt.xlabel('session_comments_given')
plt.ylabel('True_duration')
plt.show()

plt.scatter(df1['session_likes_given'], df1['True_duration'])
plt.xlabel('session_likes_given')
plt.ylabel('True_duration')
plt.show()

plt.scatter(df1['bugs_in_session'], df1['True_duration'])
plt.xlabel('bugs_in_session')
plt.ylabel('True_duration')
plt.show()



plt.scatter(df1['session_projects_added'], df1['True_duration'])
plt.xlabel('session_projects_added')
plt.ylabel('True_duration')
plt.show()


plt.scatter(df1['session_comments_given'], df1['True_duration'])
plt.xlabel('session_comments_given')
plt.ylabel('True_duration')
plt.show()

#width = 0.35   

#fig = plt.figure()
#ax = fig.add_subplot(111)
#rects1 = ax.bar(df1['session_likes_given'], df1['True_duration'], width, color='royalblue' )


#rects2 = ax.bar(df1['bugs_in_session'],  df1['True_duration'], width, color='seagreen')


#ax.set_ylabel('duration')


#plt.show()

# %%
df['Week']=pd.to_datetime(df['login_date'])
start_date='10/2/19'
end_date='10/13/19'
Week=(df['Week']>start_date )& (df['Week']< end_date)
df1=df.loc[Week]
df1.head(50)
# Out:
#      session_id  customer_id login_date projects_added likes_given  \
# 174    864133.0      14354.0   10/12/19           True       False
# 176    967732.0      40572.0   10/12/19           True       False
# 177    354260.0      29375.0   10/12/19          False       False
# 179    802529.0      23083.0   10/12/19          False        True
# 180     23570.0      38459.0   10/12/19          False        True
# 181    768035.0      23985.0   10/12/19           True        True
# 182    363747.0      23404.0   10/11/19          False        True
# 184    353787.0      73245.0   10/11/19          False        True
# 185    351540.0      14354.0   10/11/19           True        True
# 186    796561.0      29375.0   10/11/19           True       False
# 187    934455.0      40572.0   10/11/19           True       False
# 189    102067.0      23579.0   10/11/19           True        True
# 191    847651.0      34574.0   10/11/19           True        True
# ...

# %%
lowest_day= df[df.login_date =='10/12/19']
lowest_day
plt.bar(lowest_day['session_likes_given'],lowest_day['True_duration'])
plt.xlabel('session_likes_given')
plt.ylabel('True_duration')
plt.show()

plt.bar(lowest_day['bugs_in_session'], lowest_day['True_duration'])
plt.xlabel('bugs_in_session')
plt.ylabel('True_duration')
plt.show()



plt.bar(lowest_day['session_projects_added'], lowest_day['True_duration'])
plt.xlabel('session_projects_added')
plt.ylabel('True_duration')
plt.show()


plt.bar(lowest_day['session_comments_given'], lowest_day['True_duration'])
plt.xlabel('session_comments_given')
plt.ylabel('True_duration')
plt.show()

no_bugs= df[df['bugs_in_session'] == 0]

plt.bar(no_bugs['session_projects_added'], no_bugs['True_duration'])
plt.xlabel('session_projects_added')
plt.ylabel('True_duration')
plt.show()


plt.bar(no_bugs['session_comments_given'], no_bugs['True_duration'])
plt.xlabel('session_comments_given')
plt.ylabel('True_duration')
plt.show()

plt.bar(no_bugs['session_likes_given'],no_bugs['True_duration'])
plt.xlabel('session_likes_given')
plt.ylabel('True_duration')
plt.show()

no_projects= df[df['session_projects_added']== 0]

plt.bar(no_projects['bugs_in_session'], no_projects['True_duration'])
plt.xlabel('bugs_in_session')
plt.ylabel('True_duration')
plt.show()


plt.bar(no_projects['session_comments_given'], no_projects['True_duration'])
plt.xlabel('session_comments_given')
plt.ylabel('True_duration')
plt.show()

plt.bar(no_projects['session_likes_given'],no_projects['True_duration'])
plt.xlabel('session_likes_given')
plt.ylabel('True_duration')
plt.show()

no_comments= df[df['session_comments_given']== 0]

plt.bar(no_comments['session_likes_given'],no_comments['True_duration'])
plt.xlabel('session_likes_given')
plt.ylabel('True_duration')
plt.show()

plt.bar(no_comments['bugs_in_session'], no_comments['True_duration'])
plt.xlabel('bugs_in_session')
plt.ylabel('True_duration')
plt.show()

plt.bar(no_comments['session_projects_added'], no_comments['True_duration'])
plt.xlabel('session_projects_added')
plt.ylabel('True_duration')
plt.show()

no_likes= df[df['session_likes_given']== 0]

plt.bar(no_likes['bugs_in_session'], no_likes['True_duration'])
plt.xlabel('bugs_in_session')
plt.ylabel('True_duration')
plt.show()

plt.bar(no_likes['session_projects_added'], no_likes['True_duration'])
plt.xlabel('session_projects_added')
plt.ylabel('True_duration')
plt.show()

plt.bar(no_likes['session_comments_given'],no_likes['True_duration'])
plt.xlabel('session_comments_given')
plt.ylabel('True_duration')
plt.show()

# %%
highest_day= df[df.login_date =='10/28/19']
highest_day
plt.bar(highest_day['session_likes_given'],highest_day['True_duration'])
plt.xlabel('session_likes_given')
plt.ylabel('True_duration')
plt.show()

plt.bar(highest_day['bugs_in_session'], highest_day['True_duration'])
plt.xlabel('bugs_in_session')
plt.ylabel('True_duration')
plt.show()



plt.bar(highest_day['session_projects_added'], highest_day['True_duration'],width= 0.25)
plt.xlabel('session_projects_added')
plt.ylabel('True_duration')
plt.show()


plt.bar(highest_day['session_comments_given'], highest_day['True_duration'])
plt.xlabel('session_comments_given')
plt.ylabel('True_duration')
plt.show()

# %%
no_bugs= df[df['bugs_in_session'] == 0]
no_bugs.head(100)
# Out:
#      session_id  customer_id login_date projects_added likes_given  \
# 0      624205.0      80746.0   10/30/19          False        True
# 1      624241.0      24520.0   10/30/19           True        True
# 2      111002.0      32047.0   10/30/19           True        True
# 3      545113.0      23404.0   10/30/19           True        True
# 4      750269.0      40235.0   10/30/19           True        True
# ..          ...          ...        ...            ...         ...
# 218    674512.0      29375.0    10/9/19           True       False
# 224    403473.0      43549.0    10/8/19           True        True
# 229    872877.0      38459.0    10/7/19           True        True
# 230    437487.0      23548.0    10/7/19          False        True
# 232    327733.0      93486.0    10/7/19           True        True
#
#     comment_given inactive_status bug_occured  session_projects_added  \
# 0            True            True       False                     0.0
# ...

# %%
no_projects= df[df['session_projects_added']==0]
no_projects.head(100)
# Out:
#      session_id  customer_id login_date projects_added likes_given  \
# 0      624205.0      80746.0   10/30/19          False        True
# 10     696187.0      98653.0   10/29/19          False       False
# 15     920267.0      38459.0   10/29/19          False        True
# 28     440820.0      29375.0   10/27/19          False       False
# 39     652409.0      51243.0   10/26/19          False        True
# 53     864048.0      96254.0   10/26/19          False        True
# 54     309053.0      32047.0   10/26/19          False        True
# 56     629983.0      40235.0   10/25/19          False        True
# 62      74484.0      51243.0   10/24/19          False        True
# 70     162379.0      43549.0   10/24/19          False       False
# 78     507059.0      12407.0   10/22/19          False        True
# 79      51859.0      29375.0   10/22/19          False        True
# 92     512614.0      87323.0   10/21/19          False        True
# ...

# %%
highest_day= df[df.login_date =='10/28/19']
highest_day
plt.scatter(highest_day['session_likes_given'],highest_day['True_duration'])
plt.xlabel('session_likes_given')
plt.ylabel('True_duration')
plt.show()

plt.scatter(highest_day['bugs_in_session'], highest_day['True_duration'])
plt.xlabel('bugs_in_session')
plt.ylabel('True_duration')
plt.show()



plt.scatter(highest_day['session_projects_added'], highest_day['True_duration'])
plt.xlabel('session_projects_added')
plt.ylabel('True_duration')
plt.show()


plt.scatter(highest_day['session_comments_given'], highest_day['True_duration'])
plt.xlabel('session_comments_given')
plt.ylabel('True_duration')
plt.show()

# %%
lowest_day= df[df.login_date =='10/12/19']
lowest_day
plt.scatter(lowest_day['session_likes_given'],lowest_day['True_duration'])
plt.xlabel('session_likes_given')
plt.ylabel('True_duration')
plt.show()

plt.scatter(lowest_day['bugs_in_session'], lowest_day['True_duration'])
plt.xlabel('bugs_in_session')
plt.ylabel('True_duration')
plt.show()



plt.scatter(lowest_day['session_projects_added'], lowest_day['True_duration'])
plt.xlabel('session_projects_added')
plt.ylabel('True_duration')
plt.show()


plt.scatter(lowest_day['session_comments_given'], lowest_day['True_duration'])
plt.xlabel('session_comments_given')
plt.ylabel('True_duration')
plt.show()

# %%
no_bugs= df[df['bugs_in_session'] == 0]

plt.scatter(no_bugs['session_projects_added'], no_bugs['True_duration'])
plt.xlabel('session_projects_added')
plt.ylabel('True_duration')
plt.show()


plt.scatter(no_bugs['session_comments_given'], no_bugs['True_duration'])
plt.xlabel('session_comments_given')
plt.ylabel('True_duration')
plt.show()

plt.scatter(no_bugs['session_likes_given'],no_bugs['True_duration'])
plt.xlabel('session_likes_given')
plt.ylabel('True_duration')
plt.show()

# %%
no_projects= df[df['session_projects_added']== 0]

plt.scatter(no_projects['bugs_in_session'], no_projects['True_duration'])
plt.xlabel('bugs_in_session')
plt.ylabel('True_duration')
plt.show()


plt.scatter(no_projects['session_comments_given'], no_projects['True_duration'])
plt.xlabel('session_comments_given')
plt.ylabel('True_duration')
plt.show()

plt.scatter(no_projects['session_likes_given'],no_projects['True_duration'])
plt.xlabel('session_likes_given')
plt.ylabel('True_duration')
plt.show()

# %%
no_comments= df[df['session_comments_given']== 0]

plt.scatter(no_comments['session_likes_given'],no_comments['True_duration'])
plt.xlabel('session_likes_given')
plt.ylabel('True_duration')
plt.show()

plt.scatter(no_comments['bugs_in_session'], no_comments['True_duration'])
plt.xlabel('bugs_in_session')
plt.ylabel('True_duration')
plt.show()

plt.scatter(no_comments['session_projects_added'], no_comments['True_duration'])
plt.xlabel('session_projects_added')
plt.ylabel('True_duration')
plt.show()

# %%
no_likes= df[df['session_likes_given']== 0]

plt.scatter(no_likes['bugs_in_session'], no_likes['True_duration'])
plt.xlabel('bugs_in_session')
plt.ylabel('True_duration')
plt.show()

plt.scatter(no_likes['session_projects_added'], no_likes['True_duration'])
plt.xlabel('session_projects_added')
plt.ylabel('True_duration')
plt.show()

plt.scatter(no_likes['session_comments_given'],no_likes['True_duration'])
plt.xlabel('session_comments_given')
plt.ylabel('True_duration')
plt.show()

# %%
lowest_day= df[df.login_date =='10/12/19']
no_likes= lowest_day[lowest_day['session_likes_given']== 0]
no_comments= lowest_day[lowest_day['session_comments_given']== 0]
no_projects= lowest_day[lowest_day['session_projects_added']== 0]
no_bugs= lowest_day[lowest_day['bugs_in_session'] == 0]



plt.scatter(no_bugs['session_projects_added'], no_bugs['True_duration'])
plt.xlabel('session_projects_added')
plt.ylabel('True_duration')
plt.show()

plt.scatter(no_bugs['session_comments_given'], no_bugs['True_duration'])
plt.xlabel('session_comments_given')
plt.ylabel('True_duration')
plt.show()
plt.scatter(no_bugs['session_likes_given'],no_bugs['True_duration'])
plt.xlabel('session_likes_given')
plt.ylabel('True_duration')
plt.show()


plt.scatter(no_projects['bugs_in_session'], no_projects['True_duration'])
plt.xlabel('bugs_in_session')
plt.ylabel('True_duration')
plt.show()
plt.scatter(no_projects['session_comments_given'], no_projects['True_duration'])
plt.xlabel('session_comments_given')
plt.ylabel('True_duration')
plt.show()
plt.scatter(no_projects['session_likes_given'],no_projects['True_duration'])
plt.xlabel('session_likes_given')
plt.ylabel('True_duration')
plt.show()



plt.scatter(no_comments['session_likes_given'],no_comments['True_duration'])
plt.xlabel('session_likes_given')
plt.ylabel('True_duration')
plt.show()
plt.scatter(no_comments['bugs_in_session'], no_comments['True_duration'])
plt.xlabel('bugs_in_session')
plt.ylabel('True_duration')
plt.show()
plt.scatter(no_comments['session_projects_added'], no_comments['True_duration'])
plt.xlabel('session_projects_added')
plt.ylabel('True_duration')
plt.show()



plt.scatter(no_likes['bugs_in_session'], no_likes['True_duration'])
plt.xlabel('bugs_in_session')
plt.ylabel('True_duration')
plt.show()
plt.scatter(no_likes['session_projects_added'], no_likes['True_duration'])
plt.xlabel('session_projects_added')
plt.ylabel('True_duration')
plt.show()
plt.scatter(no_likes['session_comments_given'],no_likes['True_duration'])
plt.xlabel('session_comments_given')
plt.ylabel('True_duration')
plt.show()

# %%
repeat= df[df['customer_id']!= df['customer_id']].index
df.drop(repeat, inplace = True)
df.head(10)
plt.bar(df['session_likes_given'],df['True_duration'])
plt.xlabel('session_likes_given')
plt.ylabel('True_duration')
plt.show()

plt.bar(df['bugs_in_session'], df['True_duration'])
plt.xlabel('bugs_in_session')
plt.ylabel('True_duration')
plt.show()



plt.bar(df['session_projects_added'], df['True_duration'],width= 0.25)
plt.xlabel('session_projects_added')
plt.ylabel('True_duration')
plt.show()


plt.bar(df['session_comments_given'], df['True_duration'])
plt.xlabel('session_comments_given')
plt.ylabel('True_duration')
plt.show()


plt.scatter(df['session_likes_given'],df['True_duration'])
plt.xlabel('session_likes_given')
plt.ylabel('True_duration')
plt.show()

plt.scatter(df['bugs_in_session'], df['True_duration'])
plt.xlabel('bugs_in_session')
plt.ylabel('True_duration')
plt.show()



plt.scatter(df['session_projects_added'], df['True_duration'])
plt.xlabel('session_projects_added')
plt.ylabel('True_duration')
plt.show()


plt.scatter(df['session_comments_given'], df['True_duration'])
plt.xlabel('session_comments_given')
plt.ylabel('True_duration')
plt.show()

# %%
repeat= df[df['customer_id']!= df['customer_id']].index
df.drop(repeat, inplace = True)
df.head(300)
# Out:
#      session_id  customer_id login_date projects_added likes_given  \
# 0      624205.0      80746.0   10/30/19          False        True
# 1      624241.0      24520.0   10/30/19           True        True
# 2      111002.0      32047.0   10/30/19           True        True
# 3      545113.0      23404.0   10/30/19           True        True
# 4      750269.0      40235.0   10/30/19           True        True
# ..          ...          ...        ...            ...         ...
# 295    944212.0      40572.0    10/1/19           True        True
# 296    558332.0      87323.0    10/1/19           True       False
# 297    643880.0      51243.0    10/1/19           True       False
# 298    844518.0      23083.0    10/1/19           True       False
# 299    933954.0      38459.0    10/1/19           True       False
#
#     comment_given inactive_status bug_occured  session_projects_added  \
# 0            True            True       False                     0.0
# ...
